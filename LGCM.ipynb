# %% [markdown]
# <a href="https://colab.research.google.com/github/Dey313/Python-Projects/blob/main/LGCM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Hypothetical parameters
intercept_values = [80, 85, 90, 92, 95]  # Replace with actual intercept values
slope_values = [2, 1.5, 1, 0.5, 0.2]      # Replace with actual slope values
years = [2019, 2020, 2021, 2022, 2023]

# Calculate predicted placement outcomes
predicted_outcomes = [intercept + slope * (year - 2019) for intercept, slope, year in zip(intercept_values, slope_values, years)]

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.plot(years, predicted_outcomes, marker='o', linestyle='-', color='b')
plt.title('Predicted Placement Outcomes Over the Years')
plt.xlabel('Academic Year')
plt.ylabel('Predicted Placement Outcome')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Years and Learning Outcome Scores
years = np.array([2019, 2019, 2020, 2020, 2021, 2021, 2022, 2022, 2023, 2023])
learning_outcome_scores = np.array([75, 80, 85, 88, 92, 95, 89, 91, 94, 97])

# Model Parameters (hypothetical)
beta_0 = 80  # Initial status
beta_1 = 1.5  # Slope

# Calculate the predicted values based on the model
predicted_scores = beta_0 + beta_1 * (years - 2019)

# Introduce a dip in the year 2020 to 2021
predicted_scores[years == 2021] -= 5

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.scatter(years, learning_outcome_scores, label='Observed Data')
plt.plot(years, predicted_scores, label='Predicted Model', color='orange', linestyle='--')

# Highlight the dip due to COVID-19
plt.axvspan(2020.5, 2021.5, color='red', alpha=0.2, label='COVID-19 Dip')

# Labels and Title
plt.xlabel('Year')
plt.ylabel('Learning Outcome Score')
plt.title('Learning Outcome Over the Years with COVID-19 Dip')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Years and Learning Outcome Scores
years = np.array([2019, 2019, 2020, 2020, 2021, 2021, 2022, 2022, 2023, 2023])
learning_outcome_scores = np.array([75, 80, 85, 88, 92, 95, 89, 91, 94, 97])

# Model Parameters (hypothetical)
beta_0 = 80  # Initial status
beta_1 = 1.5  # Slope

# Calculate the predicted values based on the model
predicted_scores = beta_0 + beta_1 * (years - 2019)

# Introduce a dip in the year 2020 to 2021
predicted_scores[years == 2021] -= 5

# Plotting the graph
plt.figure(figsize=(10, 6))

# Scatter plot for observed data
plt.scatter(years, learning_outcome_scores, label='Observed Data')

# Plot predicted model
plt.plot(years, predicted_scores, label='Predicted Model', color='orange', linestyle='--')

# Highlight the dip due to COVID-19
plt.axvspan(2020.5, 2021.5, color='red', alpha=0.2, label='COVID-19 Dip')

# Labels and Title
plt.xlabel('Year')
plt.ylabel('Learning Outcome Score')
plt.title('Learning Outcome Over the Years with COVID-19 Dip')
plt.legend()
plt.grid(True)
plt.show()
